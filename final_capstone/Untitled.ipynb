# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('MetroVancouver_FSA_Code.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Place    91 non-null     object
#  1   Code     91 non-null     object
#  2   Country  91 non-null     object
#  3   Admin1   91 non-null     object
#  4   Admin2   91 non-null     object
#  5   Admin3   0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 4.4+ KB

# %%
def find_fsa_lat_lon(row):
    url = 'http://geogratis.gc.ca/services/geolocation/en/locate?q={}'.format(row['Code'])
    coordinates = requests.get(url).json()[0]['geometry']['coordinates']
    row['lat']= coordinates[1]
    row['lon']= coordinates[0]
    return row

df = df.apply(find_fsa_lat_lon, axis=1)

# %%
df
# Out:
#                                                 Place Code Country  \
# 0                                  Chilliwack Central  V2P  Canada
# 1                                     Chilliwack West  V2R  Canada
# 2                                Abbotsford Southeast  V2S  Canada
# 3                                Abbotsford Southwest  V2T  Canada
# 4                                Port Coquitlam South  V3C  Canada
# ..                                                ...  ...     ...
# 86  Burnaby (Government Road / Lake City / SFU / B...  V5A  Canada
# 87      Burnaby (Parkcrest-Aubrey / Ardingley-Sprott)  V5B  Canada
# 88  Vancouver (Strathcona / Chinatown / Downtown E...  V6A  Canada
# 89  Vancouver (NE Downtown / Harbour Centre / Gast...  V6B  Canada
# 90                                     Richmond South  V7A  Canada
#
#               Admin1           Admin2  Admin3        lat         lon
# 0   British Columbia       Chilliwack     NaN  49.191250 -121.907188
# 1   British Columbia       Chilliwack     NaN  49.056461 -121.971657
# 2   British Columbia       Abbotsford     NaN  49.047405 -122.286743
# 3   British Columbia       Abbotsford     NaN  49.043354 -122.348457
# 4   British Columbia  Port Coquitlam      NaN  49.256513 -122.782005
# ..               ...              ...     ...        ...         ...
# 86  British Columbia          Burnaby     NaN  49.270771 -122.925301
# 87  British Columbia          Burnaby     NaN  49.271599 -122.974701
# 88  British Columbia        Vancouver     NaN  49.283709 -123.093266
# 89  British Columbia        Vancouver     NaN  49.276421 -123.114464
# 90  British Columbia         Richmond     NaN  49.110044 -123.115989
#
# [91 rows x 8 columns]
